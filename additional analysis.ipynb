# %%
# %matplotlib inline
from import_file import *

# %% [markdown]
# # Plots

# %%
movie_list2(df[df['name'].str.contains("西游伏妖|夏有乔木|爸爸去哪|刺客聂隐娘")])

movie_list2(df[df['name'].str.contains("万万没想到|大鱼海棠|魔兽|爱乐之城|\
                                       |女巫季节|消失的子弹|蚁人|萨利机长")].sort_values(by='db_rating',ascending=True)) 
# 魔兽|小王子; 明日边缘|国王的演讲
# movie_list2(df[df['name'].str.contains("小团圆|小时代4|长城")])

# %%
df['cluster'] = kmeans_model.labels_
fig, ax = plt.subplots()
scatter_plot = ax.scatter(df['db_rating'], df['std'], c=df['cluster'], alpha=0.7, cmap='viridis', label='')
ax.scatter(cluster_rating, cluster_std, c=arange(0,6), label='Cluster center',
           s=300, cmap='viridis', edgecolor='black', lw = 1.5)
plt.plot([0,10],[std_standard, std_standard], linestyle='--', color='black', label='97% STD')
ax.axis([2,10,df['std'].min()-0.02,df['std'].max()+0.02])
plt_configure(xlabel='Rating', ylabel='STD', figsize=(6,6), legend=True)

# %%
df['cluster'] = kmeans_model.labels_
fig, ax = plt.subplots()
scatter_plot = ax.scatter(df['db_rating'], df['std'], c=df['cluster'], alpha=0.7, cmap='viridis', label='')
plt.plot([0,10],[std_standard, std_standard], linestyle='--', color='black', label='97% STD')
sub_df = df[df['name'].str.contains("神奇女侠|暮光之城 Twilight")] 
ax.scatter(sub_df.db_rating, sub_df['std'], label='',
           s=70, edgecolor='black',facecolor='red', lw=1.5) 
ax.axis([2,10,df['std'].min()-0.02,df['std'].max()+0.02])
plt_configure(xlabel='Rating', ylabel='STD', figsize=(6,6), legend=True)

# %% [markdown]
# # 3. Value Range Estimation

# %%
# np.random.randint(0,100,size=(100, 5))
df = pd.DataFrame(np.random.dirichlet(np.ones(5),size=5000), columns=['1_star','2_star','3_star','4_star','5_star'])
# df = pd.DataFrame(np.random.dirichlet([0.1,0.5,1,0.5,0.1],size=100000), columns=['1_star','2_star','3_star','4_star','5_star'])

df['db_rating']=df['1_star']*2+df['2_star']*4+df['3_star']*6+df['4_star']*8+df['5_star']*10
df['std']=(df['1_star']*(2-df['db_rating'])**2+df['2_star']*(4-df['db_rating'])**2+df['3_star']*(6-df['db_rating'])**2+ \
df['4_star']*(8-df['db_rating'])**2+df['5_star']*(10-df['db_rating'])**2)**0.5
df
# Out:
#         1_star    2_star    3_star    4_star    5_star  db_rating       std
# 0     0.120285  0.023871  0.502165  0.181001  0.172678   6.523833  2.287464
# 1     0.105672  0.386673  0.275773  0.054705  0.177176   5.622078  2.479568
# 2     0.145387  0.045201  0.419328  0.020217  0.369867   6.847954  2.790468
# 3     0.056036  0.650917  0.161853  0.073952  0.057242   4.850894  1.841596
# 4     0.068407  0.051565  0.049827  0.048212  0.781989   8.847623  2.428269
# 5     0.118307  0.278078  0.087202  0.259463  0.256951   6.517347  2.808316
# 6     0.354815  0.216906  0.202116  0.130518  0.095646   4.790547  2.671009
# 7     0.007822  0.851358  0.010674  0.129346  0.000801   4.527893  1.376108
# 8     0.068936  0.665924  0.037779  0.136508  0.090853   5.028837  2.196178
# 9     0.015842  0.654505  0.007208  0.192098  0.130346   5.533205  2.346813
# 10    0.014431  0.007186  0.017706  0.384108  0.576569   9.002398  1.416610
# 11    0.339770  0.279339  0.071621  0.218662  0.090608   4.882001  2.761908
# 12    0.401651  0.130728  0.314642  0.133222  0.019757   4.477414  2.340951
# 13    0.183276  0.206297  0.156251  0.023012  0.431165   6.624986  3.218335
# 14    0.013364  0.324513  0.102844  0.064309  0.494970   7.406019  2.777002
# 15    0.371666  0.129424  0.177967  0.212470  0.108474   5.113326  2.874650
# 16    0.162849  0.322801  0.257020  0.210546  0.046785   5.311233  2.239001
# 17    0.324915  0.206346  0.363142  0.103240  0.002357   4.503555  2.057995
# 18    0.362312  0.190745  0.173972  0.000970  0.272000   5.259204  3.219795
# 19    0.012991  0.116588  0.176872  0.689578  0.003971   7.109901  1.504717
# 20    0.265358  0.393163  0.034859  0.289075  0.017545   4.800573  2.411798
# 21    0.342740  0.002315  0.510401  0.008475  0.136069   5.185638  2.653473
# 22    0.389260  0.082915  0.089560  0.044220  0.394045   5.941752  3.610820
# 23    0.134325  0.137740  0.088373  0.584959  0.054602   6.575545  2.362707
# 24    0.021110  0.189222  0.180170  0.590920  0.018578   6.793266  1.768134
# 25    0.245336  0.418868  0.120363  0.006906  0.208527   5.028840  2.832269
# 26    0.280071  0.522115  0.055836  0.057696  0.084283   4.288011  2.284291
# 27    0.747217  0.048874  0.063088  0.058821  0.081999   3.359023  2.592969
# 28    0.091257  0.228296  0.054288  0.045936  0.580223   7.591146  3.051042
# 29    0.335673  0.124150  0.243703  0.017837  0.278638   5.559235  3.194157
# ...        ...       ...       ...       ...       ...        ...       ...
# 4970  0.172170  0.459757  0.039515  0.070138  0.258420   5.565762  2.969926
# 4971  0.358662  0.090791  0.367114  0.032654  0.150778   5.052192  2.783252
# 4972  0.379733  0.012532  0.038390  0.195781  0.373563   6.341815  3.573396
# 4973  0.092531  0.168257  0.075763  0.117481  0.545967   7.712193  2.902985
# 4974  0.243435  0.396962  0.222216  0.018016  0.119372   4.745854  2.427332
# 4975  0.061011  0.020250  0.114327  0.466865  0.337547   7.999372  2.080360
# 4976  0.114689  0.034197  0.601274  0.212715  0.037127   6.046789  1.847837
# 4977  0.035551  0.214760  0.436685  0.053853  0.259151   6.572586  2.337054
# 4978  0.037648  0.036949  0.005482  0.687765  0.232155   8.079663  1.700209
# 4979  0.013000  0.480476  0.158374  0.198985  0.149165   5.981680  2.304811
# 4980  0.064815  0.388281  0.030052  0.102765  0.414088   6.826059  2.990694
# 4981  0.038184  0.016876  0.397104  0.184120  0.363715   7.636610  2.134451
# 4982  0.080259  0.019225  0.149619  0.143745  0.607151   8.356608  2.469178
# 4983  0.058960  0.057487  0.004257  0.769003  0.110294   7.628368  1.833695
# 4984  0.015614  0.299276  0.008995  0.449750  0.226365   7.143952  2.357786
# 4985  0.226269  0.066529  0.221838  0.417070  0.068295   6.069184  2.577330
# 4986  0.232424  0.092373  0.310093  0.325727  0.039383   5.694544  2.434750
# 4987  0.350425  0.012738  0.442571  0.156403  0.037863   5.037086  2.441715
# 4988  0.214334  0.080980  0.094938  0.546646  0.063102   6.326401  2.615902
# 4989  0.838040  0.027154  0.028643  0.005212  0.100952   3.007764  2.489950
# 4990  0.269880  0.052754  0.129254  0.237703  0.310410   6.532017  3.188011
# 4991  0.220303  0.074642  0.186177  0.397925  0.120954   6.249171  2.699682
# 4992  0.019860  0.101202  0.474303  0.285271  0.119364   6.766152  1.785075
# 4993  0.130598  0.343521  0.314461  0.184406  0.027014   5.267436  2.024068
# 4994  0.125930  0.139921  0.099834  0.522106  0.112209   6.709482  2.440279
# 4995  0.458116  0.069589  0.344259  0.045672  0.082364   4.449160  2.589135
# 4996  0.340689  0.135852  0.270105  0.224239  0.029115   4.930480  2.492660
# 4997  0.227334  0.323604  0.248387  0.159639  0.041037   4.926882  2.252847
# 4998  0.250922  0.188363  0.239696  0.185625  0.135394   5.532411  2.731000
# 4999  0.192988  0.193347  0.446480  0.019518  0.147667   5.471056  2.454007
#
# [5000 rows x 7 columns]

# %%
df['douban_url']=''
df['name']=''

# %%
# %time
fig, ax = plt.subplots()
scatter_plot = ax.scatter(df.db_rating, df['std'], alpha=0.1)
ax.axis([2,10,0,4])
plt.gca().set_aspect('equal')
plt_configure(xlabel='Rating', ylabel='STD')
# Out:
# Wall time: 0 ns

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.cluster import KMeans

X = df[['1_star','2_star','3_star','4_star','5_star']].as_matrix()

n_clusters = 6
kmeans_model = KMeans(n_clusters=n_clusters, random_state=1).fit(X)

# %%
df['cluster'] = kmeans_model.labels_
fig, ax = plt.subplots()
scatter_plot = ax.scatter(df['db_rating'], df['std'], c=df['cluster'], alpha=0.7, cmap='viridis')
ax.axis([2,10,df['std'].min()-0.02,df['std'].max()+0.02])
plt_configure(xlabel='Rating', ylabel='STD', figsize=(6,6))

# %%
turn_scatter_into_interactive(fig, scatter_plot, df, 'D:\movie_output\clusters_test.html', show_ratings_num=False, click=True, show_distribution=True)
# Out:
# <a class='btn btn-default' style="text-decoration: none;;"
#     href="D:\movie_output\clusters_test.html" target='_blank'>
#     Interactive Scatter Plot</a>

# %%
def prettyfloat(float):
    return "%0.1f" % float

vmin, vmax = df['cluster'].min(), df['cluster'].max()
norm = mpl.colors.Normalize(vmin=vmin, vmax=vmax)
cmap = mpl.cm.get_cmap('viridis')
colors = cmap(norm(arange(vmin, vmax+1)))

# %%
x=arange(1,6) # 5 rating types
for cluster, color in zip(kmeans_model.cluster_centers_, colors):
    plt.figure()
    rating_avg=np.dot(cluster, arange(2,12,2))
    plt.bar(x, cluster, alpha=0.7, color=color)
    plt.ylim([0,0.5*1.1])
    plt_configure(title='Rating: '+prettyfloat(rating_avg), figsize=(3.5,2.5))
align_figures()
# Out:
# <img style="margin:0" align="left" src="..."/><img style="margin:0" align="left" src="..."/><img style="margin:0" align="left" src="..."/><img style="margin:0" align="left" src="..."/><img style="margin:0" align="left" src="..."/><img style="margin:0" align="left" src="...

# %%
X = df[['1_star','2_star','3_star','4_star','5_star']].as_matrix()
cluster_range = arange(1,10)
grid = GridSearchCV(KMeans(random_state=1), {'n_clusters': cluster_range}, cv=5, n_jobs=-1) 
grid.fit(X)

plt.plot(cluster_range, grid.cv_results_['mean_test_score'], label='test')
plt.plot(cluster_range, grid.cv_results_['mean_train_score'], label='training')
plt_configure(figsize=(4,3), xlabel='Number of clusters', ylabel='Score', legend=True)

# %%
## 4.1 Mean Shift

# %%
# bandwidth = estimate_bandwidth(X, quantile=0.2, n_samples=500)

# ms = MeanShift(bandwidth=bandwidth, bin_seeding=True)
# ms.fit(X)
# labels = ms.labels_
# cluster_centers = ms.cluster_centers_

# labels_unique = np.unique(labels)
# n_clusters = len(labels_unique)

# print("number of estimated clusters : %d" % n_clusters)
